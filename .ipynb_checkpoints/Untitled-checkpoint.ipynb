# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import mpld3
from mpld3 import plugins
import pandas as pd
import seaborn as sb
sb.set_style('darkgrid')
mpld3.enable_notebook()

# %%
fig, ax = plt.subplots(subplot_kw=dict(axisbg='#EEEEEE'))
ax.grid(color='white', linestyle='solid')

N = 50
scatter = ax.scatter(np.random.normal(size=N),
                     np.random.normal(size=N),
                     c=np.random.random(size=N),
                     s = 1000 * np.random.random(size=N),
                     alpha=0.3,
                     cmap=plt.cm.jet)

labels = ["Point {0}".format(i) for i in range(N)]
tooltip = plugins.PointLabelTooltip(scatter, labels)
plugins.connect(fig, tooltip)

ax.set_title("D3 Scatter Plot", size=18);

mpld3.save_html(fig,"test.html")
# mpld3.fig_to_html(fig,"test2.html")

# %%
fig, ax = plt.subplots()
points = ax.scatter(np.random.rand(40), np.random.rand(40),
                    s=300, alpha=0.3)

labels = ["Point {0}".format(i) for i in range(40)]
tooltip = plugins.PointLabelTooltip(points, labels)

plugins.connect(fig, tooltip)

# %%
np.random.seed(9615)

# generate df
N = 100
df = pd.DataFrame((.1 * (np.random.random((N, 5)) - .5)).cumsum(0),
                  columns=['a', 'b', 'c', 'd', 'e'],)

# plot line + confidence interval
fig, ax = plt.subplots()
ax.grid(True, alpha=0.3)

for key, val in df.iteritems():
    l, = ax.plot(val.index, val.values, label=key)
    ax.fill_between(val.index,
                    val.values * .5, val.values * 1.5,
                    color=l.get_color(), alpha=.4)

# define interactive legend

handles, labels = ax.get_legend_handles_labels() # return lines and labels
interactive_legend = plugins.InteractiveLegendPlugin(zip(handles,
                                                         ax.collections),
                                                     labels,
                                                     alpha_unsel=0.5,
                                                     alpha_over=1.5, 
                                                     start_visible=True)
plugins.connect(fig, interactive_legend)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Interactive legend', size=20)

mpld3.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ed726efc5e91> in <module>()
#      19
#      20 handles, labels = ax.get_legend_handles_labels() # return lines and labels
# ---> 21 interactive_legend = plugins.InteractiveLegendPlugin(zip(handles,
#      22                                                          ax.collections),
#      23                                                      labels,
#
# AttributeError: module 'mpld3.plugins' has no attribute 'InteractiveLegendPlugin'

# %%
sites_df = pd.read_csv("raw_data/ZayoHackathonData_Sites.csv")

# %%
sites_df.head()
# Out:
#       ﻿Site ID   Account ID  Building ID   Market            Site Address  \
# 0  Site-000001  Acct-000025  Bldg-115472  Atlanta     953 Donnelly Ave SW
# 1  Site-000002  Acct-001331  Bldg-115472  Atlanta     953 Donnelly Ave SW
# 2  Site-000003  Acct-001359  Bldg-115475  Atlanta           3159 Royal Dr
# 3  Site-000004  Acct-001360  Bldg-115475  Atlanta           3159 Royal Dr
# 4  Site-000005  Acct-000009  Bldg-115476  Atlanta  1593 Northeast Expy NE
#
#          City State Postal Code  Network Proximity On Zayo Network Status
# 0     Atlanta    GA       30310             116.91    Not on Zayo Network
# 1     Atlanta    GA       30310             116.91    Not on Zayo Network
# 2  Alpharetta    GA       30005             979.44        On Zayo Network
# 3  Alpharetta    GA       30022             979.44        On Zayo Network
# 4     Atlanta    GA       30329             177.41    Not on Zayo Network

# %%
sites_df['Market'].unique()
# Out:
# array(['Atlanta', 'Dallas', 'Denver'], dtype=object)

# %%
sites_df['Market'].value_counts().head(10)
# Out:
# Atlanta    10248
# Dallas      9737
# Denver      6643
# Name: Market, dtype: int64

# %%
ax = sites_df['Network Proximity'].plot()

# %%
sites_gb_market = sites_df.groupby(['Market'])

# %%
sites_gb_market.get_group("Dallas").head(5)
# Out:
#         ﻿Site ID   Account ID  Building ID  Market              Site Address  \
# 238  Site-000239  Acct-000055  Bldg-115721  Dallas  225 E John Carpenter Fwy
# 239  Site-000240  Acct-001372  Bldg-115721  Dallas  225 E John Carpenter Fwy
# 240  Site-000241  Acct-001387  Bldg-115721  Dallas  225 E John Carpenter Fwy
# 246  Site-000247  Acct-000062  Bldg-115837  Dallas      17201 Waterview Pkwy
# 247  Site-000248  Acct-000102  Bldg-115837  Dallas      17201 Waterview Pkwy
#
#        City State Postal Code  Network Proximity On Zayo Network Status
# 238  Irving    TX       75062             205.22    Not on Zayo Network
# 239  Irving    TX       75062             205.22    Not on Zayo Network
# 240  Irving    TX       75062             205.22    Not on Zayo Network
# 246  Dallas    TX       75252            9180.22        On Zayo Network
# 247  Dallas    TX       75252            9180.22        On Zayo Network

# %%
sites_gb_market['On Zayo Network Status'].transform('value_counts')
sites_df['counts'] = sites_gb_market['On Zayo Network Status'].transform('value_counts')
# on_network = sites_gb_market.agg({'On Zayo Network Status':pd.Series.value_counts})
# sites_df.value_counts('On Zayo Network Status')

# on_network

# %%
ax = average_network_proximity.reset_index().plot(x='Market',kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d312c007d947> in <module>()
# ----> 1 ax = average_network_proximity.reset_index().plot(x='Market',kind='bar')
#
# NameError: name 'average_network_proximity' is not defined
